# %%
from issue_measurement import main

main()
# Out:
# {"ts": "2025-10-28T09:17:17.547782Z", "event": "RUN", "stage": "START", "message": "Starting integrity and quality checks"}
# {"ts": "2025-10-28T09:17:17.567282Z", "event": "INTEGRITY_OF_OUTPUT_FILE", "check": "File writable", "result": "PASS", "path": "pytorch_issues_last6months.csv"}
# {"ts": "2025-10-28T09:17:17.673075Z", "event": "INTEGRITY_OF_OUTPUT_FILE", "check": "File modified externally", "result": "PASS", "path": "pytorch_issues_last6months.csv", "prev_hash": "b551a0ff96dcba9ca422cfdf0e1fcea9de9013edd8ae1538a6c323f018ab58a1", "current_hash": "b551a0ff96dcba9ca422cfdf0e1fcea9de9013edd8ae1538a6c323f018ab58a1", "prev_mtime": 1761568702.9616354, "current_mtime": 1761568702.9616354}
# {"ts": "2025-10-28T09:17:17.673679Z", "event": "ACCESSIBILITY_OF_DATA", "check": "API URL format", "result": "PASS", "url": "https://api.github.com/repos/pytorch/pytorch/issues"}
# {"ts": "2025-10-28T09:17:17.674214Z", "event": "ACCESSIBILITY_OF_DATA", "check": "Token provided", "result": "FAIL", "reason": "No token set"}
# {"ts": "2025-10-28T09:17:18.292491Z", "event": "ACCESSIBILITY_OF_DATA", "check": "API accessibility", "result": "PASS", "status_code": 200}
# {"ts": "2025-10-28T09:17:18.375903Z", "event": "ACCESSIBILITY_OF_DATA", "check": "Rate limit availability", "result": "PASS", "remaining": 59}
# {"ts": "2025-10-28T09:17:19.232815Z", "event": "FETCH_NEW_ISSUES", "check": "Page processed", "result": "PASS", "page": 1, "items_returned": 100, "items_added": 14}
# {"ts": "2025-10-28T09:17:20.274240Z", "event": "FETCH_NEW_ISSUES", "check": "Page processed", "result": "PASS", "page": 2, "items_returned": 100, "items_added": 0}
# {"ts": "2025-10-28T09:17:21.217197Z", "event": "FETCH_NEW_ISSUES", "check": "Page processed", "result": "PASS", "page": 3, "items_returned": 100, "items_added": 0}
# {"ts": "2025-10-28T09:17:22.309383Z", "event": "FETCH_NEW_ISSUES", "check": "Page processed", "result": "PASS", "page": 4, "items_returned": 100, "items_added": 11}
# {"ts": "2025-10-28T09:17:23.536054Z", "event": "FETCH_NEW_ISSUES", "check": "Page processed", "result": "PASS", "page": 5, "items_returned": 93, "items_added": 17}
# {"ts": "2025-10-28T09:17:23.537256Z", "event": "FETCH_NEW_ISSUES", "check": "Summary", "result": "PASS", "total_added": 42}
# {"ts": "2025-10-28T09:17:23.540973Z", "event": "FETCH_NEW_ISSUES", "check": "Append", "result": "PASS", "appended": 42, "path": "pytorch_issues_last6months.csv"}
# {"ts": "2025-10-28T09:17:23.542598Z", "event": "DATA_QUALITY_CHECKS", "check": "Duplicate issue IDs", "result": "PASS", "duplicates": []}
# {"ts": "2025-10-28T09:17:23.542950Z", "event": "DATA_QUALITY_CHECKS", "check": "New issues fetched", "result": "PASS", "count": 42}
# {"ts": "2025-10-28T09:17:23.543404Z", "event": "DATA_QUALITY_CHECKS", "check": "Missing record consistency", "result": "PASS", "total_records": 315, "total_unique": 315}
# {"ts": "2025-10-28T09:17:23.584084Z", "event": "PREDICTION_CHECKS", "check": "Predicted values", "result": "PASS", "predicted_open": 53.5, "predicted_closed": 9.5}
# {"ts": "2025-10-28T09:17:23.584469Z", "event": "PREDICTION_CHECKS", "check": "Warning thresholds", "result": "FAIL", "warnings": ["A"]}
# {"ts": "2025-10-28T09:17:23.765332Z", "event": "PREDICTION_CHECKS", "check": "Visualization of summarized data", "result": "PASS", "image_path": "weekly_open_closed_issues.png"}
# {"ts": "2025-10-28T09:17:23.765804Z", "event": "RUN", "stage": "END", "message": "All quality checks completed successfully"}

# %%
from information_quality import visualize_quality_results

visualize_quality_results("information_quality.log")
# Out:
# /Users/siminsu/Library/CloudStorage/OneDrive-Chalmers/Documents/2_Code/software_metrics_course/module3_information_quality/information_quality.py:135: UserWarning: The figure layout has changed to tight
#   plt.tight_layout(rect=[0, 0, 1, 0.98])
